# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pvcircuit as pvc

# %%
si= pvc.Junction('si')
si
# Out:
# si: <tandem.Junction class>
#  Eg = 1.10 eV, TC = 25.0 C, Jext = 40.0 mA/cm2
#  Gsh = 0 S, Rser = 0 Ω, area = 1 cm2
#  pn = -1, beta = 15, gamma = 0, JLC = 0.0
#      n    J0ratio       J0
#     db       1      1.314e-16
#    1.00    10.00    1.314e-15
#    2.00    10.00    3.625e-09

# %%
silight = si.plot('Si')
si.Jext = 0
sidark = si.plot('Si')
si.Jext = 0.04

# %%
WB417 = pvc.Tandem3T()
WB417
# Out:
# Tandem3T: <tandem.Tandem3T class>
# T = 25.0 C, Rz= 2.3 Ω, Rt= 0 Ω, Rr = 0.2 Ω
#
# top: <tandem.Junction class>
#  Eg = 1.87 eV, TC = 25.0 C, Jext = 13.1 mA/cm2
#  Gsh = 1e-08 S, Rser = 0 Ω, area = 1 cm2
#  pn = -1, beta = 0, gamma = 0, JLC = 0.0
#      n    J0ratio       J0
#     db       1      3.593e-29
#    1.00    80.00    2.875e-27
#    2.00    22.00    4.170e-15
#
# bot: <tandem.Junction class>
#  Eg = 1.42 eV, TC = 25.0 C, Jext = 12.8 mA/cm2
#  Gsh = 5e-05 S, Rser = 0.2 Ω, area = 0.9 cm2
#  pn = 1, beta = 5, gamma = 0, JLC = 0.0
#      n    J0ratio       J0
#     db       1      8.771e-22
#    1.00    10.00    8.771e-21
#    2.00    15.00    1.405e-11
# RBB_dict: {'method': 'JFG', 'mrb': 10.0, 'J0rb': 0.5, 'Vrb': 0.0}

# %%
fig, axs, sp = WB417.plot(pnts=101)
# Out:
# MPP: 101pnts , 1215.6422 ms
# axs[0]: 101pnts , 49492.5878 ms
# axs[1]: 101pnts , 5157.4628 ms

# %%
axs[0].set_xlim(-1.8,1.5)
axs[0].set_ylim(-1.5, 1)
axs[1].set_xlim(-15, 15)
axs[1].set_ylim(-10, 15)
# Out:
# (-10.0, 15.0)

# %%
fig

# %%
sp
# Out:
# SpecialPoints: <tandem.IV3T class>
# {'name': 'SpecialPoints', 'meastype': 'CZ', 'shape': (8,)}
# sizes(8, 8)
#
#   #      mIro     mIzo     mIto     Vzt      Vrz      Vtr      mIA      mIB       VA       VB     mPtot    mIxhex   mIyhex   Vxhex    Vyhex
#  Voc3   0.00     0.00     0.00     1.442    1.044   -2.485    0.00     0.00     1.044   -1.442    0.00     0.00     0.00     2.777    1.205
#  Isc3  -11.52    -1.60    13.10    0.000    0.000   -0.000   -11.52    13.10    0.000    0.000    0.00    -17.41    -1.84    0.000    0.000
# IzoVtr -12.67    0.00     12.67    1.300   -1.300   -0.000   -12.67    12.67   -1.300   -1.300    0.00    -17.92    0.00     0.919   -1.501
