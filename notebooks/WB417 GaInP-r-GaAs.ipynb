# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pvcircuit as pvc

# %% [markdown]
# # Modeled 3T GaInP/s/GaAs (WB417) performance from SI of:
# ### Geisz, et al., Cell Reports Physical Science __2__, 100677 (2021).

# %%
WB417 = pvc.Tandem3T()

# %%
WB417.set(name='WB417', Rz = 2.3)
WB417.top.set(Eg=1.87, J0ratio=[ 80., 22.], Jext=0.0131, Gsh=1e-8)   
WB417.bot.set(Eg=1.419, J0ratio=[10., 15.], Jext=0.0128, Gsh= 5e-5)
WB417.bot.set(Rser=0.2, beta=5., area=0.89,  RBB='JFG')

# %%
WB417.controls()
# Out:
# VBox(children=(HBox(children=(Text(value='WB417', description='name', layout=Layout(width='200px')), BoundedFl…

# %%
pnts=51

# %%
CZ_figs, CZ_axs, CZ_iv, CZ_sp = WB417.plot(meastype='CZ', pnts=pnts)
# Out:
# axs[0]: 51pnts , 15.6627 s
# axs[1]: 51pnts , 2.1078 s

# %%
CR_figs, CR_axs, CR_iv, CR_sp = WB417.plot(meastype='CR', pnts=pnts)
# Out:
# axs[0]: 51pnts , 14.4979 s
# axs[1]: 51pnts , 2.0057 s

# %%
CT_figs, CT_xs, CT_iv, CT_sp = WB417.plot(meastype='CT', pnts=pnts)
# Out:
# axs[0]: 51pnts , 15.4451 s
# axs[1]: 51pnts , 2.0124 s

# %%
CZ_axs[1].set_xlim(-1,3)
CZ_axs[1].set_ylim(-2,1.5)
CZ_axs[3].set_xlim(-25,5)
CZ_axs[3].set_ylim(-35,25)
# Out:
# (-35.0, 25.0)

# %%
CZ_figs[1]

# %%
CZ_figs[3]

# %%
CZ_sp
# Out:
# WB417 SpecialPoints: <tandem.IV3T class>
# {'name': 'WB417 SpecialPoints', 'meastype': 'CZ', 'shape': (8,)}
# sizes(8, 8)
#
#   #      mIro     mIzo     mIto     Vzt      Vrz      Vtr      mIA      mIB       VA       VB     mPtot    mIxhex   mIyhex   Vxhex    Vyhex
#  Voc3   0.00     0.00     0.00     1.442    1.044   -2.485    0.00     0.00     1.044   -1.442    0.00     0.00     0.00     2.777    1.205
#  Isc3  -11.39    -1.73    13.10    0.000    0.000   -0.000   -11.39    13.10    0.000    0.000    0.00    -17.32    -1.98    0.000    0.000
# VrzIto -11.76    11.76    0.00     1.469   -0.000   -1.469   -11.76    0.00    -0.000   -1.469    -0.00    -8.32    13.58    2.077   -0.000
# VztIro  0.00    -13.10    13.10    0.000    1.073   -1.073    0.00     13.10    1.073   -0.000    0.00     -9.26   -15.13    0.758    1.238
# VtrIzo -12.57    0.00     12.57    1.309   -1.310    0.001   -12.57    12.57   -1.310   -1.309    -0.01   -17.78    -0.00    0.926   -1.513
#  MPP   -10.82    -1.82    12.66    1.296    0.903   -2.199   -10.82    12.66    0.903   -1.296    26.19   -16.61    -2.11    2.472    1.043
#  MPPV  -11.05    -1.48    12.50    1.312    0.875   -2.187   -11.05    12.50    0.875   -1.312    26.07   -16.65    -1.69    2.474    1.010
#  MPPI  -11.00    -1.57    12.58    1.306    0.882   -2.187   -11.00    12.58    0.882   -1.306    26.12   -16.67    -1.82    2.470    1.018
