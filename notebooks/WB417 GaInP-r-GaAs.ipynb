# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pvcircuit as pvc

# %%
WB417 = pvc.Tandem3T()

# %%
WB417.update(name='WB417', Rz = 2.3)
WB417.top.update(Eg=1.87, J0ratio=[ 80., 22.], Jext=0.0131, Gsh=1e-8)   
WB417.bot.update(Eg=1.419, J0ratio=[10., 15.], Jext=0.0128, Gsh= 5e-5)
WB417.bot.update(Rser=0.2, beta=5., area=0.9,  RBB='JFG')

# %%
WB417
# Out:
# WB417: <tandem.Tandem3T class>
# T = 25.0 C, Rz= 2.3 Ω, Rt= 0 Ω, Rr = 0.2 Ω
#
# top: <tandem.Junction class>
#  Eg = 1.87 eV, TC = 25.0 C, Jext = 13.1 mA/cm2
#  Gsh = 1e-08 S, Rser = 0 Ω, area = 1 cm2
#  pn = -1, beta = 0, gamma = 0, JLC = 0.0
#      n    J0ratio       J0
#     db       1      3.593e-29
#    1.00    80.00    2.875e-27
#    2.00    22.00    4.170e-15
#
# bot: <tandem.Junction class>
#  Eg = 1.42 eV, TC = 25.0 C, Jext = 12.8 mA/cm2
#  Gsh = 5e-05 S, Rser = 0.2 Ω, area = 0.9 cm2
#  pn = 1, beta = 5, gamma = 0, JLC = 0.0
#      n    J0ratio       J0
#     db       1      8.771e-22
#    1.00    10.00    8.771e-21
#    2.00    15.00    1.405e-11
# RBB_dict: {'method': 'JFG', 'mrb': 10.0, 'J0rb': 0.5, 'Vrb': 0.0}

# %%
pnts=101

# %%
CZV_fig, CZI_fig, CZ_axs, CZ_iv, CZ_sp = WB417.plot(meastype='CZ', pnts=pnts)
# Out:
# axs[0]: 101pnts , 71.3383 s
# axs[1]: 101pnts , 7.7118 s

# %%
CR_Vfig, CR_Ifig, CR_axs, CR_iv, CR_sp = WB417.plot(meastype='CR', pnts=pnts)
# Out:
# axs[0]: 101pnts , 67.9085 s
# axs[1]: 101pnts , 7.3299 s

# %%
CT_Vfig, CT_Ifig, CT_xs, CT_iv, CT_sp = WB417.plot(meastype='CT', pnts=pnts)
# Out:
# axs[0]: 101pnts , 67.4940 s
# axs[1]: 101pnts , 7.5128 s

# %%
hex_Vfig, hex_Ifig, hex_axs, hex_iv, hex_sp = WB417.plot(meastype='CZ',oper='dev2hex', pnts=pnts)
# Out:
# axs[0]: 101pnts , 72.0235 s
# axs[1]: 101pnts , 7.8028 s

# %%
hex_axs[0].set_xlim(-1,3)
hex_axs[0].set_ylim(-2,1.5)
hex_axs[1].set_xlim(-25,5)
hex_axs[1].set_ylim(-35,25)
# Out:
# (-35.0, 25.0)

# %%
hex_Vfig

# %%
hex_Ifig
